# %%
# import matplotlib
# matplotlib.use('nbagg')

# %%
#Importing needed packages

import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import LogNorm

import astropy.units as u
from astropy.utils.data import download_file
from astropy.io import fits  # We use fits to open the actual data file

from astropy.utils import data

from astropy.wcs import WCS
from astropy import wcs
import sys
from astropy.visualization import make_lupton_rgb
from sklearn import preprocessing #only works for dimensions <=2

#For plotting Gaussian
from scipy.optimize import curve_fit
from astropy import modeling
from scipy.stats import norm
import math
import seaborn as sns
from scipy.signal import find_peaks
import scipy.stats as stats
import scipy.stats

# %% [markdown]
# # Calling and plotting individual outflow files

# %%
#Calling FITS file for co_25_74

location = "/Users/RuheeJanmohamed/Desktop/Data/co_25_74_M0.fits"

hdul = fits.open(location)

hdu_25_74 = hdul[0]

#print(hdu_25_74.header)
#print(hdu_25_74.shape)

co_25_74 = hdu_25_74.data

# %%
plt.imshow(co_25_74,cmap='Reds',origin='lower')

#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_75_124

location = "/Users/RuheeJanmohamed/Desktop/Data/co_75_124_M0.fits"

hdul = fits.open(location)

hdu_75_124 = hdul[0]

co_75_124 = hdu_75_124.data

# %%
plt.imshow(co_75_124,cmap='Reds',origin='lower')

#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_125_174

location = "/Users/RuheeJanmohamed/Desktop/Data/co_125_174_M0.fits"

hdul = fits.open(location)

hdu_125_174 = hdul[0]

co_125_174 = hdu_125_174.data

# %%
plt.imshow(co_125_174,cmap='Reds',origin='lower')

#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_175_224

location = "/Users/RuheeJanmohamed/Desktop/Data/co_175_224_M0.fits"

hdul = fits.open(location)

hdu_175_224 = hdul[0]

co_175_224 = hdu_175_224.data

# %%
plt.imshow(co_175_224,cmap='Reds',origin='lower')
 
#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_225_274

location = "/Users/RuheeJanmohamed/Desktop/Data/co_225_274_M0.fits"

hdul = fits.open(location)

hdu_225_274 = hdul[0]

co_225_274 = hdu_225_274.data

# %%
plt.imshow(co_225_274,cmap='Reds',origin='lower')
 
#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_275_299

location = "/Users/RuheeJanmohamed/Desktop/Data/co_275_299_M0.fits"

hdul = fits.open(location)

hdu_275_299 = hdul[0]

co_275_299 = hdu_275_299.data

# %%
plt.imshow(co_275_299,cmap='Reds',origin='lower')
 
#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_300_224

location = "/Users/RuheeJanmohamed/Desktop/Data/co_300_324_M0.fits"

hdul = fits.open(location)

hdu_300_324 = hdul[0]

co_300_324 = hdu_300_324.data

# %%
plt.imshow(co_300_324,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_325_374

location = "/Users/RuheeJanmohamed/Desktop/Data/co_325_374_M0.fits"

hdul = fits.open(location)

hdu_325_374 = hdul[0]

co_325_374 = hdu_325_374.data

# %%
plt.imshow(co_325_374,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_375_424

location = "/Users/RuheeJanmohamed/Desktop/Data/co_375_424_M0.fits"

hdul = fits.open(location)

hdu_375_424 = hdul[0]

co_375_424 = hdu_375_424.data

# %%
plt.imshow(co_375_424,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_425_474

location = "/Users/RuheeJanmohamed/Desktop/Data/co_425_474_M0.fits"

hdul = fits.open(location)

hdu_425_474 = hdul[0]

co_425_474 = hdu_425_474.data

# %%
plt.imshow(co_425_474,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_475_524

location = "/Users/RuheeJanmohamed/Desktop/Data/co_475_524_M0.fits"

hdul = fits.open(location)

hdu_475_524 = hdul[0]

co_475_524 = hdu_475_524.data

# %%
plt.imshow(co_475_524,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#Calling FITS file for co_525_574

location = "/Users/RuheeJanmohamed/Desktop/Data/co_525_574_M0.fits"

hdul = fits.open(location)

hdu_525_574 = hdul[0]

co_525_574 = hdu_525_574.data

# %%
plt.imshow(co_525_574,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %% [markdown]
# # Subplots of individual outflows

# %%
fig, axis = plt.subplots(2,6, figsize=(16,6))

co_maps = [
    co_25_74,co_75_124,co_125_174,co_175_224,co_225_274,co_275_299,
    co_300_324,co_325_374,co_375_424,co_425_474,co_475_524,co_525_574
]



for ax,co_map in zip(axis.flat[0:6],co_maps[0:6]):
    ax.imshow(co_map,cmap='Reds',origin='lower')

    
for ax,co_map in zip(axis.flat[6:12],co_maps[6:12]):
    ax.imshow(co_map,cmap='Blues',origin='lower')  
    
plt.tight_layout()

# %%
#20 to 74

plt.subplot(1,2,1)
plt.imshow(co_25_74,cmap='Reds',origin='lower')
plt.title("25 to 74")

plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

#75 to 124

plt.subplot(1,2,2)
plt.imshow(co_75_124,cmap='Reds',origin='lower')
plt.title("75 to 124")

plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#125 to 174

plt.subplot(1,2,1)
plt.imshow(co_125_174,cmap='Reds',origin='lower')
plt.title("125 to 174")
#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line



#175 to 224 
plt.subplot(1,2,2)
plt.imshow(co_125_174,cmap='Reds',origin='lower')
plt.title("175 to 224")
#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#225 to 274
plt.subplot(1,2,1)
plt.imshow(co_225_274,cmap='Reds',origin='lower')
plt.title("225 to 274")

#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

#275 to 299
plt.subplot(1,2,2)
plt.imshow(co_275_299,cmap='Reds',origin='lower')
plt.title('275 to 299')
 
#Bottom
plt.plot([205,240],[220,100],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[100,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([310,284],[320,230],'k-',linestyle='--') #1st right hand line
plt.plot([340,284],[290,230],'k-',linestyle='--') #1st left hand line

# %%
#300 to 324

plt.subplot(1,2,1)
plt.imshow(co_300_324,cmap='Blues',origin='lower')
plt.title('300 to 324')

#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

#325 to 374
plt.subplot(1,2,2)
plt.title('325 to 374')
plt.imshow(co_325_374,cmap='Blues',origin='lower')
 
#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#375 to 424
plt.subplot(1,2,1)
plt.imshow(co_375_424,cmap='Blues',origin='lower')
plt.title('375 to 424')

#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

#425 to 474

plt.subplot(1,2,2)
plt.imshow(co_425_474,cmap='Blues',origin='lower')
plt.title('425 to 474')

#Bottom
plt.plot([205,250],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %%
#475 to 524

plt.subplot(1,2,1)
plt.imshow(co_475_524,cmap='Blues',origin='lower')
plt.title('475 to 524')

#Bottom
plt.plot([205,290],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

#525 to 574


plt.subplot(1,2,2)
plt.imshow(co_525_574,cmap='Blues',origin='lower')
plt.title('525 to 574')

#Bottom
plt.plot([205,290],[220,360],'k-',linestyle='--') #1st right hand line
plt.plot([170,205],[350,220],'k-',linestyle='--') #1st left hand line

#Top
plt.plot([285,260],[230,130],'k-',linestyle='--') #1st right hand line
plt.plot([215,285],[160,230],'k-',linestyle='--') #1st left hand line

# %% [markdown]
# # Creating RGB maps

# %%
#Creating blank image to take spot for G

blackblankimage = np.zeros(shape=[450, 450], dtype=np.float64)

#Try making a white background

# %%
#Normalizing data for co_25_74 and co_525_574

co_25_74[co_25_74<0.0] = 0.0 # get rid of negatives
co_25_74 = co_25_74/np.max(co_25_74) # normalize

co_525_574[co_525_574<0.0] = 0.0 # get rid of negatives
co_525_574 = co_525_574/np.max(co_525_574) # normalize

# %%
# Plotting RGB for co_25_74 and co_525_574

rgb_cube = np.stack((co_25_74, blackblankimage, co_525_574),axis=-1)

plt.figure(figsize=(9,9))
plt.imshow(rgb_cube,origin='lower')
plt.title('25~74 and 525~574')
print(rgb_cube.shape)

#Run transparancy element in imshow for background
# Out:
# (450, 450, 3)

# %%
#Normalizing data for co_75_124 and co_475_524

co_75_124[co_75_124<0.0] = 0.0 # get rid of negatives
co_75_124 = co_75_124/np.max(co_75_124) # normalize

co_475_524[co_475_524<0.0] = 0.0 # get rid of negatives
co_475_524 = co_475_524/np.max(co_475_524) # normalize

# %%
# Plotting RGB for co_75_124 and co_475_524

rgb_cube = np.stack((co_75_124, blackblankimage, co_475_524),axis=-1)
plt.figure(figsize=(9,9))
plt.imshow(rgb_cube,origin='lower')
plt.title('75~124 and 475~524')
plt.plot
print(rgb_cube.shape)
# Out:
# (450, 450, 3)

# %%
#Normalizing data for co_125_174 and co_425_474

co_125_174[co_125_174<0.0] = 0.0 # get rid of negatives
co_125_174 = co_125_174/np.max(co_125_174) # normalize

co_425_474[co_425_474<0.0] = 0.0 # get rid of negatives
co_425_474 = co_425_474/np.max(co_425_474) # normalize

# %%
# Plotting RGB for co_125_174 and co_425_474

rgb_cube = np.stack((co_125_174, blackblankimage, co_425_474),axis=-1)
plt.figure(figsize=(9,9))
plt.imshow(rgb_cube,origin='lower')
plt.title('125~174 and 425~474')
plt.plot
print(rgb_cube.shape)
# Out:
# (450, 450, 3)

# %%
#Normalizing data for co_175_224 and co_375_424

co_175_224[co_175_224<0.0] = 0.0 # get rid of negatives
co_175_224 = co_175_224/np.max(co_175_224) # normalize

co_375_424[co_375_424<0.0] = 0.0 # get rid of negatives
co_375_424 = co_375_424/np.max(co_375_424) # normalize

# %%
# Plotting RGB for co_175_224 and co_375_424

rgb_cube = np.stack((co_175_224, blackblankimage, co_375_424),axis=-1)
plt.figure(figsize=(9,9))
plt.imshow(rgb_cube,origin='lower')
plt.title('175~224 and 375~424')
plt.plot
print(rgb_cube.shape)
# Out:
# (450, 450, 3)

# %%
#Normalizing data for co_225_274 and co_325_374

co_225_274[co_225_274<0.0] = 0.0 # get rid of negatives
co_225_274 = co_225_274/np.max(co_225_274) # normalize

co_325_374[co_325_374<0.0] = 0.0 # get rid of negatives
co_325_374 = co_325_374/np.max(co_325_374) # normalize


#Adding in co_275_299
co_275_299[co_275_299<0.0] = 0.0 # get rid of negatives
co_275_299 = co_275_299/np.max(co_275_299) # normalize

# %%
# Plotting RGB for co_225_274 and co_325_374

rgb_cube = np.stack((co_225_274, blackblankimage, co_325_374),axis=-1)
plt.figure(figsize=(9,9))
plt.imshow(rgb_cube,origin='lower')
plt.title('225~274 and 325~374')
plt.plot
print(rgb_cube.shape)
# Out:
# (450, 450, 3)

# %%
#Normalizing data for co_275_299 and co_300_324 (Closest to origin)

co_300_324[co_300_324<0.0] = 0.0 # get rid of negatives
co_300_324 = co_300_324/np.max(co_300_324) # normalize


co_275_299[co_275_299<0.0] = 0.0 # get rid of negatives
co_275_299 = co_275_299/np.max(co_275_299) # normalize

# %%
# Plotting RGB for co_275_299 and co_300_324

rgb_cube = np.stack((co_275_299, blackblankimage, co_300_324),axis=-1)
plt.figure(figsize=(9,9))
plt.imshow(rgb_cube,origin='lower')
plt.title('275~299 and 300~324')
plt.plot
print(rgb_cube.shape)
# Out:
# (450, 450, 3)

# %% [markdown]
# # Fitting a Gaussian to the Southern sky of the Moment 0 Map of BHR

# %%
#Fitting a Gaussian to 

location = "/Users/RuheeJanmohamed/Desktop/Data/co_zero_south.fits"

hdul = fits.open(location)

hdu_zero_south = hdul[0]

co_zero_south = hdu_zero_south.data

# %%
plt.imshow(co_zero_south,cmap='Blues',origin='lower')

# %%
#Taking a cut of the image to show two maximums
cut = co_zero_south[150,:]

plt.plot(range(450),cut)

# %%
#Taking cut from 140 to 150, and averages these together

cut = co_zero_south[140:150,:]
cut[cut<0]=0
avg_cut = np.mean(cut,axis=0)

plt.plot(range(150,200),avg_cut[150:200])

# %%
range?

# %%
#A for loop that takes each line and plots it over each other

for i in range(10):
    cut = co_zero_south[50+(i*15):60+(i*15),100:300]
    cut[cut<0]=0
    avg_cut = np.mean(cut,axis=0)
    plt.plot(range(200),avg_cut)

# %%
#how to fit peaks with gaussians (Astr 303 report)
#give gaussain a good beginning guess

# %%
#Fitting Gausian to one curve first

cut = co_zero_south[140:150,:]
cut[cut<0]=0
avg_cut = np.mean(cut,axis=0)

plt.plot(range(450),avg_cut)

#Trying to plot Gaussian    

def Gauss(x,amp,mean,sigma):
    f = amp*np.exp(-(x-mean)**2/(2*sigma**2))
    return f

xdata=np.arange(200,250)
ydata=avg_cut[200:250]

#amp,mean,sigma,offset
p0 = (np.max(ydata),xdata[np.argmax(ydata)],5)

p_opt,p_cov = curve_fit(Gauss,xdata,ydata,p0)
plt.plot(xdata,Gauss(xdata,p_opt[0],p_opt[1],p_opt[2]))

print(p_opt)
print(np.max(ydata))
print(xdata[ydata==np.max(ydata)])

x2data=np.arange(150,200)
y2data=avg_cut[150:200]

p0 = (np.max(y2data),x2data[np.argmax(y2data)],5)

p_opt,p_cov = curve_fit(Gauss,x2data,y2data,p0)
plt.plot(x2data,Gauss(x2data,p_opt[0],p_opt[1],p_opt[2]))

print(p_opt) #use as inital guess
print(np.max(y2data)) #intensity (i)
print(x2data[y2data==np.max(y2data)])

print(np.sqrt(np.diag(p_cov))) #covariance matrix (how they interact with each other)
# Out:
# [1609.38052145  225.13340935    6.36907968]
# 1671.3671875
# [227]
# [1160.16267986  179.18547533    7.86070823]
# 1139.9028930664062
# [179]
# [22.0855476   0.17267479  0.17365615]

# %%
#do the left side of the outflow at 100 and march upwards
#print out p_opt, p_cov, and y value 
#change y to i or intensity

#Question
# How to bin the lines?

# %%
#Line 100 (Left)
cut = co_zero_south[70:75,:]
cut[cut<0]=0
avg_cut = np.mean(cut,axis=0)

plt.plot(range(450),avg_cut)

#Fitting Gaussian

xdata=np.arange(120,205)
idata=avg_cut[120:205]

#plt.plot(range(140,205),avg_cut[140:205])

p0 = (np.max(idata),xdata[np.argmax(idata)],5)

p_opt,p_cov = curve_fit(Gauss,xdata,idata,p0)
plt.plot(xdata,Gauss(xdata,p_opt[0],p_opt[1],p_opt[2]))

print(p_opt) #use as inital guess
print(np.max(idata)) #intensity (i)
print(xdata[idata==np.max(idata)])

print(np.sqrt(np.diag(p_cov)))
# Out:
# [381.70276044 146.89469405   5.91029695]
# 398.0677185058594
# [145]
# [15.226849    0.27224907  0.27224908]

# %%
plt.imshow(co_zero_south,cmap='Blues',origin='lower')
plt.axvline(205)
plt.axvline(120)
plt.show()

# %% [markdown]
# ## Fitting Gaussians to all 8 maps

# %%
for ax,co_map in zip(axis.flat[0:6],co_maps[0:6]):
    ycut_list=[(70+(i*5),70+((i+1)*5)) for i in range(26)]

# %%
off_x1 = 100
off_x2 = 300


for ycut in ycut_list:
    cut = co_zero_south[ycut[0]:ycut[1],off_x1:off_x2]
    cut[cut<0]=0
    avg_cut = np.mean(cut,axis=0)
    xdata=np.arange(110,175)
    idata=avg_cut[110:175]
    
    p0 = (np.max(idata),xdata[np.argmax(idata)],5)

    p_opt,p_cov = curve_fit(Gauss,xdata,idata,p_opt)
    
    plt.plot(range(200),avg_cut,c='k')
    plt.plot(xdata,Gauss(xdata,p_opt[0],p_opt[1],p_opt[2]))

# %% [markdown]
# #Possible way of doing this
#
# - Defining Gaussian and the fitting under one function
# - In this function, call the images (But how to store them?)
# - Then call the function outside
#
# ex://
#
# def my_function(x,y):
#  ..
#  ..
#  ..
#
#     Image_list = [co_25_74,co_75_124,co_125_174,co_175_224,co_225_274,co_275_299]
#
#
# for y in ylist:
#    my_function(x,y)

# %%
for ax,co_map in zip(axis.flat[0:6],co_maps[0:6]):
    Red_image_list = np.array(co_maps[0:6])

# %%
def Gauss(x,amp,mean,sigma):
    f = amp*np.exp(-(x-mean)**2/(2*sigma**2))
    return f

def Fitting_Red(xdata,idata):

    #plotting
    cut = Red_image_list[ycut[0]:ycut[1],:]
    cut[cut<0]=0
    avg_cut = np.mean(cut,axis=0)
    
    p0 = (np.max(idata),xdata[np.argmax(idata)],5)

    p_opt,p_cov = curve_fit(Gauss,xdata,idata,p0)
    
    plt.plot(range(450),avg_cut,c='k')
    plt.plot(xdata,Gauss(xdata,p_opt[0],p_opt[1],p_opt[2]))
 
    
ycut_list=[(70+(i*5),70+((i+1)*5)) for i in range(26)]

for ycut in ycut_list:
    Fitting_Red(np.arange(50,175),avg_cut[50:175])
# Out:
# /Users/RuheeJanmohamed/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/RuheeJanmohamed/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:153: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /Users/RuheeJanmohamed/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/RuheeJanmohamed/opt/anaconda3/lib/python3.8/site-packages/numpy/core/_methods.py:153: RuntimeWarning: invalid value encountered in true_divide
#   ret = um.true_divide(
# /Users/RuheeJanmohamed/opt/anaconda3/lib/python3.8/site-packages/numpy/core/fromnumeric.py:3334: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# ...
